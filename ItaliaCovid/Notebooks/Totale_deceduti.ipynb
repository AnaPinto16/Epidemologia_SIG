# %% [markdown]
# # COVID-19 ITÁLIA
#
# ##########################Total de óbitos############################
#
# ### Ana Pinto a93660

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from qgis.core import *
from qgis.PyQt.QtGui import *
from qgis.PyQt.QtCore import *
from IPython.display import Image

# %% [markdown]
# Start Qgis with GUI and start a project

# %%
QgsApplication.setPrefixPath(r'C:\\OSGeo4W64\\apps\\qgis', True)
qgs = QgsApplication([], True)
qgs.initQgis()
sys.path.append(r'C:\OSGeo4W64\apps\qgis\python\plugins')
project = QgsProject.instance()

# %%
path = "C:\\OSGeo4W64\\bin\\SIG\\IT\\Shapes\\ITA_adm1.shp"
map_layer = QgsVectorLayer(path, 'Italy map', 'ogr')

if not map_layer.isValid():
    print("Failed to load the layer!")
else:
    project.addMapLayer(map_layer)
    print("Sucess")
# Out:
# Sucess

# %%
csv_path = "file:///C:\\OSGeo4W64\\bin\\SIG\\IT\\dpc-covid19-ita-regioni.csv?delimiter=,'"
csv_layer = QgsVectorLayer(csv_path, 'Data', 'delimitedtext')

if not csv_layer.isValid():
    print('Layer failed to load!')
else:
    project.addMapLayer(csv_layer)
    print("Sucess")
# Out:
# Sucess

# %%
joinName = 'denominazione_regione'
targetName = 'NAME_1'

joinObject = QgsVectorLayerJoinInfo()
joinObject.setJoinFieldName(joinName)
joinObject.setTargetFieldName(targetName)
joinObject.setJoinLayerId(csv_layer.id())
joinObject.setUsingMemoryCache(True)
joinObject.setJoinLayer(csv_layer)
flag = map_layer.addJoin(joinObject)

# %%
deceduti_layer = map_layer.clone()
deceduti_layer.setName("Number of deceduti")

for field in deceduti_layer.fields():
    print(field.name()+" Load")
# Out:
# ID_0 Load
# ISO Load
# NAME_0 Load
# ID_1 Load
# NAME_1 Load
# TYPE_1 Load
# ENGTYPE_1 Load
# NL_NAME_1 Load
# VARNAME_1 Load
# Data_data Load
# Data_stato Load
# Data_lat Load
# Data_long Load
# Data_ricoverati_con_sintomi Load
# Data_totale_ospedalizzati Load
# Data_isolamento_domiciliare Load
# Data_totale_positivi Load
# Data_variazione_totale_positivi Load
# Data_nuovi_positivi Load
# Data_dimessi_guariti Load
# Data_deceduti Load
# Data_totale_casi Load
# Data_field_15 Load
# Data_field_16 Load
# Data_field_17 Load
# Data_field_18 Load
# Data_field_19 Load
# Data_field_20 Load

# %%
from qgis.utils import iface


label_settings = QgsPalLayerSettings()
label_settings.drawBackground = True
label_settings.fieldName = 'Data_deceduti'

text_format = QgsTextFormat()

text_format.setFont(QFont("Arial", 12))
text_format.setSize(55) 
                     
background_color = QgsTextBackgroundSettings()
text_format.setColor(QColor("dimgrey"))

background_color.setEnabled(False)
text_format.setBackground(background_color )
label_settings.setFormat(text_format)

deceduti_layer.setLabeling(QgsVectorLayerSimpleLabeling(label_settings))
deceduti_layer.setLabelsEnabled(True)
deceduti_layer.triggerRepaint()

# %%
from qgis.PyQt import QtGui

myOpacity = 1

myTargetField = 'Data_deceduti'
myRangeList = []

myMin = 0
myMax = 50
myLabel = '0-50'
myColour = QtGui.QColor('#ffe6e6')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 50
myMax = 100
myLabel = '50-100'
myColour = QtGui.QColor('#ffb3b3')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 100
myMax = 400
myLabel = '100 - 400'
myColour = QtGui.QColor('#ff8080')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)


myMin = 400
myMax = 800
myLabel = '400 - 800'
myColour = QtGui.QColor('#ff4d4d')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 800
myMax = 1000
myLabel = '1200 - 1400'
myColour = QtGui.QColor('#ff1a1a')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 1000
myMax = 1800
myLabel = '1000 - 1800'
myColour = QtGui.QColor('#e60000')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 1800
myMax = 2800
myLabel = '1800 - 2800'
myColour = QtGui.QColor('#b30000')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 2800
myMax = 3800
myLabel = '2800-3800'
myColour = QtGui.QColor('#800000')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)


myMin = 3800
myMax = 10000
myLabel = '4800-10000'
myColour = QtGui.QColor('#4d0000')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)

myMin = 10000
myMax = 20000
myLabel = '10000-20000'
myColour = QtGui.QColor('#000000')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)





myMin = -1
myMax = -1
myLabel = 'Sem Dados'
myColour = QtGui.QColor('#333333')
mySymbol = QgsSymbol.defaultSymbol(deceduti_layer.geometryType())
mySymbol.setColor(myColour)
myRange = QgsRendererRange(myMin, myMax, mySymbol, myLabel)
myRangeList.append(myRange)
myRenderer = QgsGraduatedSymbolRenderer('', myRangeList)
myClassificationMethod = QgsApplication.classificationMethodRegistry().method("EqualInterval")
myRenderer.setClassificationMethod(myClassificationMethod)
myRenderer.setClassAttribute(myTargetField)

deceduti_layer.setRenderer(myRenderer)

# %%
xt = deceduti_layer.extent()
width  = 1024
height = int(width*xt.height()/xt.width())

project = QgsProject().instance()
project.addMapLayers([deceduti_layer])
manager = project.layoutManager()
layoutName = 'Totale Deceduti'
layouts_list = manager.printLayouts()
for layout in layouts_list:
    if layout.name() == layoutName:
        manager.removeLayout(layout)
        
layout = QgsPrintLayout(project)
layout.initializeDefaults()
layout.setName(layoutName)
manager.addLayout(layout)




pc = layout.pageCollection()
pc.page(0).attemptResize(QgsLayoutSize(width,height,QgsUnitTypes.LayoutMillimeters))


map = QgsLayoutItemMap(layout)
map.setRect(20,20,20,20)
map.setLayers([deceduti_layer])



ms = QgsMapSettings()
ms.setLayers([deceduti_layer])
ms.setExtent(xt)
map.setExtent(xt)


layout.addLayoutItem(map)



map.attemptMove(QgsLayoutPoint(0,0,QgsUnitTypes.LayoutMillimeters))
map.attemptResize(QgsLayoutSize(width,height,QgsUnitTypes.LayoutMillimeters))


map.setBackgroundColor(QColor(250,250,250))

legend = QgsLayoutItemLegend(layout)

legend.setReferencePoint(6)
legend.setScale(3)
legend.attemptMove(QgsLayoutPoint(0,height,QgsUnitTypes.LayoutMillimeters))

layout.addLayoutItem(legend)
legend.setLegendFilterByMapEnabled(True)

legend.setLinkedMap(map)

exporter = QgsLayoutExporter(manager.layoutByName("Totale Deceduti"))


image = exporter.renderPageToImage(0)
image = exporter.renderPageToImage(0)

from IPython.display import Image
imgbuf= QBuffer()
imgbuf.open( QIODevice.ReadWrite )
image.save( imgbuf,"PNG" )
image.save('C:/OSGeo4W64/bin/SIG/IT/Geographic_distribution_totale_deceduti.png',"PNG")
Image( imgbuf.data() )
